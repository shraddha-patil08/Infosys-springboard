# %%
# !pip install supervision
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 24.8 MB/s eta 0:00:00
# ...

# %%
import cv2
import supervision as sv
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/Mydrive')
# Out:
# Mounted at /content/Mydrive

# %%
# %%writefile /content/config.yaml
#
#  path: /content/Mydrive/MyDrive/ANPR_and_ATCC_for_Smart_Traffic_Management/dataset
#  train: /content/Mydrive/MyDrive/ANPR_and_ATCC_for_Smart_Traffic_Management/dataset/images/train
#  val: /content/Mydrive/MyDrive/ANPR_and_ATCC_for_Smart_Traffic_Management/dataset/images/val
#  nc: 1
#
#  names: [
#      'license_plate'
#  ]
# Out:
# Writing /content/config.yaml

# %%
# !yolo task=detect mode=train model="/content/best_2.pt" data="/content/config.yaml" epochs=100
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model="/content/runs/detect/train/weights/best.pt" data="/content/config.yaml"
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/Mydrive/MyDrive/ANPR_and_ATCC_for_Smart_Traffic_Management/dataset/labels/val.cache... 95 images, 0 backgrounds, 0 corrupt: 100% 95/95 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 6/6 [00:03<00:00,  1.68it/s]
#                    all         95         95      0.969      0.978       0.98      0.852
# Speed: 3.6ms preprocess, 12.2ms inference, 0.0ms loss, 12.2ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#get bounding box predictions
from ultralytics import YOLO

path="/content/image.jpg"

yolo_model=YOLO("/content/runs/detect/train/weights/best.pt")
bbox_results=yolo_model.predict(path,verbose=False)

# %%
all_box_list = []
all_conf_list = []


for bbox_result in bbox_results:
    boxes = bbox_result.boxes
    box_list = []
    conf_list = []
    for box in boxes:
        box_data = box.data[0][:4]
        box_data = [int(x) for x in box_data]
        conf = round(float(box.conf), 2)
        if(conf>=0.5):
            box_list.append(box_data)
            conf_list.append(conf)

    all_box_list.append(box_list)
    all_conf_list.append(conf_list)

# %%
all_conf_list
# Out:
# [[0.87, 0.81, 0.71]]

# %%
# for i in bbox_results:
#   print(i.boxes)

print(all_box_list[0])
print(all_conf_list)


# for i, box in enumerate(boxes):
#   print(i, box)
# Out:
# [[121, 430, 214, 453], [762, 409, 845, 428], [593, 351, 654, 370]]
# [[0.87, 0.81, 0.71]]

# %%
ori_path = path
print(ori_path)
ori_image = cv2.imread(ori_path)
ori_image = cv2.cvtColor(ori_image, cv2.COLOR_BGR2RGB)
# Out:
# /content/image.jpg

# %%
from ultralytics.utils.plotting import Annotator


annotator = Annotator(ori_image)
boxes = all_box_list
confs = all_conf_list

# %%
for i in all_box_list[0]:
  print(i)
# Out:
# [121, 430, 214, 453]
# [762, 409, 845, 428]
# [593, 351, 654, 370]

# %%
import matplotlib.pyplot as plt

# for i, box in enumerate(boxes):
#   print(i)
box = all_box_list[0][0]
confs = 0.120
annotator.box_label(box=box, label="license_plate ", color=(30, 240, 100))

# Get Plate Object
x1, y1, x2, y2 = box
x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
roi = ori_image[y1:y2, x1:x2]
plt.imshow(roi)
plt.show()

# Show Image
frame = annotator.result()
plt.imshow(frame)
plt.show()
